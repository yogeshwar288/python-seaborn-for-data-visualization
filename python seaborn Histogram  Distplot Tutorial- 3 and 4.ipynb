# %% [markdown]
# # python seaborn tutorial part-3

# %% [markdown]
# # how to draw Histogram/seaborn Distplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(tips_df['size'])
plt.show()

# %%
sns.distplot(tips_df['tip'])

# %%
sns.distplot(tips_df['total_bill'])

# %%
#parameters
'''
sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)
'''
# Out:
# '\nsns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)\n'

# %%
sns.distplot(tips_df['total_bill'],bins=15)

# %%
sns.distplot(tips_df['total_bill'],bins=20)

# %%
sns.distplot(tips_df['total_bill'],bins=20,hist=False)

# %%
sns.distplot(tips_df['total_bill'],bins=20,hist=True,kde=False)

# %%
sns.distplot(tips_df['total_bill'],bins=20,hist=True)

# %%
sns.distplot(tips_df['total_bill'],bins=20,hist=True,rug=True)

# %%
sns.distplot(tips_df['total_bill'],bins=20,fit=norm)

# %%
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm)

# %%
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='y')

# %%
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='y',vertical=True)

# %%
plt.figure(figsize=(16,9))
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='y',vertical=False)

# %%
plt.figure(figsize=(16,9))
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='y',vertical=False,norm_hist=True)

# %%
plt.figure(figsize=(16,9))
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='g',vertical=False,norm_hist=True)

# %%
plt.figure(figsize=(16,9))
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='g',vertical=False,norm_hist=True,axlabel='Total Bill')

# %%
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=20,kde=False,fit=norm,color='g',
             axlabel='Total Bill',label='total bill')
plt.title('total bill histogram',fontsize=20)
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Python seaborn part-4

# %% [markdown]
# # Histogram Distplot Parametar

# %%
#parameters,how we can use
'''
sns.distplot(
    a,
    bins=None,
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
)
'''
# Out:
# '\nsns.distplot(\n    a,\n    bins=None,\n    hist=True,\n    kde=True,\n    rug=False,\n    fit=None,\n    hist_kws=None,\n    kde_kws=None,\n    rug_kws=None,\n    fit_kws=None,\n    color=None,\n    vertical=False,\n    norm_hist=False,\n    axlabel=None,\n    label=None,\n    ax=None,\n)\n'

# %%
#background change karna ho to sns.set(parametar) function a use karte hai

'''
sns.set(
    context='notebook',
    style='darkgrid',
    palette='deep',
    font='sans-serif',
    font_scale=1,
    color_codes=True,
    rc=None,
)
'''
# Out:
# "\nsns.set(\n    context='notebook',\n    style='darkgrid',\n    palette='deep',\n    font='sans-serif',\n    font_scale=1,\n    color_codes=True,\n    rc=None,\n)\n"

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=20,fit=norm,color='g',
             axlabel='Total Bill',label='total bill')
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill")
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",hist_kws={'color':'r','edgecolor':'b'})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",hist_kws={'color':'y'})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",hist_kws={'color':'k'})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",hist_kws={'color':'g','edgecolor':'b'})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--'})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
#anather type
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws=histkws_parameter)
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9},rug=True)
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9},
             rug=True,
             rug_kws={'color':'g','edgecolor':'r','linestyle':'--','alpha':0.8})
plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9},
             rug=True,
             rug_kws={'color':'g','edgecolor':'r','linestyle':'--','alpha':0.8},
             kde=False,
             fit=norm,
             fit_kws={'color':'y','linewidth':2,'linestyle':'--','alpha':0.9})

plt.title('total bill histogram',fontsize=20)#for title
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9},
             rug=True,
             rug_kws={'color':'g','edgecolor':'r','linestyle':'--','alpha':0.8},
             kde=False,
             fit=norm,
             fit_kws={'color':'y','linewidth':2,'linestyle':'--','alpha':0.9})

plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
#for total_bill
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill")
#fortips
sns.distplot(tips_df['tip'],bins=bins,color='y',label="tips")
#for size
sns.distplot(tips_df['size'],bins=bins,color='b',label="size")
plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
plt.legend()#for label
plt.xticks()
plt.show()

# %%
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.set(style='darkgrid')
plt.figure(figsize=(18'9))
histkws_parameter={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8}
sns.distplot(tips_df['total_bill'],bins=bins,color='g',label="totalbill",
             hist_kws={'color':'g','edgecolor':'y','linewidth':5,'linestyle':'--','alpha':0.8},
             kde_kws={'color':'b','linewidth':2,'linestyle':'--','alpha':0.9},
             rug=True,
             rug_kws={'color':'g','edgecolor':'r','linestyle':'--','alpha':0.8},
             kde=False,
             fit=norm,
             fit_kws={'color':'y','linewidth':2,'linestyle':'--','alpha':0.9})
#fortips
sns.distplot(tips_df['tip'],bins=bins,color='y',label="tips")
#for size
sns.distplot(tips_df['size'],bins=bins,color='b',label="size")


plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
plt.legend()#for label
plt.xticks()
plt.show()
# Out:
#   File "<ipython-input-70-af8481ae61c8>", line 3
#     plt.figure(figsize=(18'9))
#                               ^
# SyntaxError: EOL while scanning string literal

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(12,7))
#for total_bill
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.distplot(tips_df['total_bill'],color='g',label="totalbill")
#fortips
sns.distplot(tips_df['tip'],color='y',label="tips")
#for size
sns.distplot(tips_df['size'],color='b',label="size")
plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
plt.legend()#for label
plt.xticks()
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(18,9))
#for total_bill
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.distplot(tips_df['total_bill'],color='g',label="totalbill")
#fortips
#sns.distplot(tips_df['tip'],color='y',label="tips")
#for size
#sns.distplot(tips_df['size'],color='b',label="size")
plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
plt.legend()#for label
plt.xticks()
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(18,9))
#for total_bill
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.distplot((tips_df['total_bill'],tips_df['tip']))
#fortips
#sns.distplot(tips_df['tip'],color='y',label="tips")
#for size
#sns.distplot(tips_df['size'],color='b',label="size")
plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
#plt.legend()#for label
plt.xticks()
plt.show()

# %%
sns.set(style='darkgrid')
plt.figure(figsize=(18,9))
#for total_bill
bins=[1,5,10,15,20,25,30,35,40,45,50,55]
sns.distplot(tips_df['total_bill','tip','size'])
#fortips
#sns.distplot(tips_df['tip'],color='y',label="tips")
#for size
#sns.distplot(tips_df['size'],color='b',label="size")
plt.title('total bill histogram',fontsize=20)#for title
plt.xlabel('totalbill',fontsize=15)
#plt.legend()#for label
plt.xticks()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('total_bill', 'tip', 'size')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-cbd641aba8d2> in <module>
#       3 #for total_bill
# ...
